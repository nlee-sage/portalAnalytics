# %%
from dotenv import dotenv_values
import snowflake.connector
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, Latex

# %%
# there is probably a better way to do this. But this works for now
data_tables = ['AD','ELITE', 'GENIE', 'HTAN', 'NF', 'PSYCHENCODE']
table_names = ['SAGE.PORTAL_RAW.' + d for d in data_tables]
table_names

# %%
config = dotenv_values(".env")
conn = snowflake.connector.connect(
    user=config['USER'],
    account=config['ACCOUNT_IDENTIFIER'],
    authenticator="externalbrowser", # FOR browser-based SSO for authentication since account uses Google account for login. It is organization-username
    warehouse=config['WAREHOUSE'],
    database=config['DATABASE'],
    role=config['ROLE'],
    login_timeout = 60,
    network_timeout=30,
    socket_timeout=10
)

# %%
# create cursor
cur = conn.cursor()

# Try to join all the tables together

sf_tables = {}

for t in table_names: 
    query = f"""
        SELECT * FROM {t}
    """

    cur.execute(query)

    # Retrieve results
    df = pd.concat([d for d in cur.fetch_pandas_batches()])
    df = df.reset_index(drop=True)
    df['TABLE'] = t
    sf_tables[t] = df

cur.close()
# Out:
# True

# %%
comb_df = pd.concat(sf_tables.values()).reset_index(drop=True)

original_shape = comb_df.shape
original_cols = sorted(comb_df.columns)
comb_df = comb_df.dropna(how='all', axis =1)
# removing empty lists and changing all nonetypes to nans
comb_df = comb_df.replace('[]', np.nan).fillna(value=np.nan)
# cleanup lists and values for new lines, double spaces and quotes
comb_df = comb_df.apply(lambda x: x.str.replace('\n|\s+|"', '', regex = True), axis = 1)
# drop empty columns
comb_df = comb_df.dropna(how='all', axis =1)
comb_df = comb_df[sorted(comb_df.columns)]

display(Markdown(f"""
|ORIGINAL|NEW|
|---|---|
|{original_shape}|{comb_df.shape}|
"""))
# Out:
# |ORIGINAL|NEW|
# |---|---|
# |(522977, 105)|(522977, 83)|

# %%
comb_df
# Out:
#        ACCESSTYPE  AGE ALIGNMENTMETHOD        ANALYSISTYPE       ASSAY  \
# 0             NaN  NaN             NaN  genotypeimputation  [snpArray]
# 1             NaN  NaN             NaN  genotypeimputation  [snpArray]
# 2             NaN  NaN             NaN  genotypeimputation  [snpArray]
# 3             NaN  NaN             NaN  genotypeimputation  [snpArray]
# 4             NaN  NaN             NaN  genotypeimputation  [snpArray]
# ...           ...  ...             ...                 ...         ...
# 522972        NaN  NaN             NaN                 NaN         NaN
# 522973        NaN  NaN             NaN                 NaN         NaN
# 522974        NaN  NaN             NaN                 NaN         NaN
# 522975        NaN  NaN             NaN                 NaN     ATACSeq
# 522976        NaN  NaN             NaN                 NaN         NaN
#
#        ASSAYTARGET BENEFACTORID BRODMANNAREA CELLTYPE CHROMOSOME  ... STUDYID  \
# 0              NaN   syn5550382          NaN      NaN        NaN  ...     NaN
# 1              NaN   syn5550382          NaN      NaN        NaN  ...     NaN
# 2              NaN   syn5550382          NaN      NaN        NaN  ...     NaN
# 3              NaN   syn5550382          NaN      NaN        NaN  ...     NaN
# 4              NaN   syn5550382          NaN      NaN        NaN  ...     NaN
# ...            ...          ...          ...      ...        ...  ...     ...
# 522972         NaN  syn20729790          NaN      NaN        NaN  ...     NaN
# 522973         NaN  syn20729790          NaN      NaN        NaN  ...     NaN
# 522974         NaN  syn20729790          NaN      NaN        NaN  ...     NaN
# 522975         NaN   syn5584622          NaN      NaN        NaN  ...     NaN
# 522976         NaN  syn25606136          NaN      NaN        NaN  ...     NaN
#
#        STUDYNAME                        TABLE TERMINALDIFFERENTIATIONPOINT  \
# 0            NaN           SAGE.PORTAL_RAW.AD                          NaN
# 1            NaN           SAGE.PORTAL_RAW.AD                          NaN
# 2            NaN           SAGE.PORTAL_RAW.AD                          NaN
# 3            NaN           SAGE.PORTAL_RAW.AD                          NaN
# 4            NaN           SAGE.PORTAL_RAW.AD                          NaN
# ...          ...                          ...                          ...
# 522972       NaN  SAGE.PORTAL_RAW.PSYCHENCODE                          NaN
# 522973       NaN  SAGE.PORTAL_RAW.PSYCHENCODE                          NaN
# 522974       NaN  SAGE.PORTAL_RAW.PSYCHENCODE                          NaN
# 522975       NaN  SAGE.PORTAL_RAW.PSYCHENCODE                          NaN
# 522976       NaN  SAGE.PORTAL_RAW.PSYCHENCODE                          NaN
#
#        TISSUE TRANSPLANTATIONTYPE TREATMENTTYPE TUMORTYPE TYPE VERSION
# 0         NaN                 NaN           NaN       NaN  NaN     NaN
# 1         NaN                 NaN           NaN       NaN  NaN     NaN
# 2         NaN                 NaN           NaN       NaN  NaN     NaN
# 3         NaN                 NaN           NaN       NaN  NaN     NaN
# 4         NaN                 NaN           NaN       NaN  NaN     NaN
# ...       ...                 ...           ...       ...  ...     ...
# 522972    NaN                 NaN           NaN       NaN  NaN     NaN
# 522973    NaN                 NaN           NaN       NaN  NaN     NaN
# 522974    NaN                 NaN           NaN       NaN  NaN     NaN
# 522975    NaN                 NaN           NaN       NaN  NaN     NaN
# 522976    NaN                 NaN           NaN       NaN  NaN     NaN
#
# [522977 rows x 83 columns]

# %%
# pull out only columns found in all tables
# cols = {}

# for k,v in sf_tables.items(): 
#     cols[k] = set(v.columns)

# u = set.intersection(*cols.values())
# u

# %%
cols
# Out:
# {'SAGE.PORTAL_RAW.AD': {'ANALYSISTYPE',
#   'ASSAY',
#   'ASSAYTARGET',
#   'BENEFACTORID',
#   'CELLTYPE',
#   'CHROMOSOME',
#   'CONSORTIUM',
#   'CREATEDBY',
#   'CREATEDON',
#   'CURRENTVERSION',
#   'DATAFILEHANDLEID',
#   'DATAFILESIZEBYTES',
#   'DATASUBTYPE',
#   'DATATYPE',
#   'FILEFORMAT',
#   'GRANTS',
#   'GROUPS',
#   'ID',
#   'INDIVIDUALID',
#   'INDIVIDUALIDSOURCE',
#   'ISCONSORTIUMANALYSIS',
#   'ISMODELSYSTEM',
#   'ISMULTISPECIMEN',
#   'LIBRARYPREP',
#   'METABOLITETYPE',
#   'METADATATYPE',
#   'MODELSYSTEMNAME',
#   'MODELSYSTEMTYPE',
#   'MODIFIEDBY',
#   'MODIFIEDON',
#   'NAME',
#   'NUCLEICACIDSOURCE',
#   'ORGAN',
#   'PARENTID',
#   'PROJECTID',
#   'RESOURCETYPE',
#   'SEX',
#   'SPECIES',
#   'SPECIMENID',
#   'SPECIMENIDSOURCE',
#   'STUDY',
#   'TABLE',
#   'TISSUE',
#   'TREATMENTTYPE'},
#  'SAGE.PORTAL_RAW.ELITE': {'ANALYSISTYPE',
#   'ASSAY',
#   'CONSENT',
#   'CONSORTIUM',
#   'CURRENTVERSION',
#   'DATASUBTYPE',
#   'DATATYPE',
#   'ETAG',
#   'FILEFORMAT',
#   'GRANTS',
#   'ID',
#   'ISCONSORTIUMANALYSIS',
#   'ISMODELSYSTEM',
#   'ISMULTISPECIMEN',
#   'LIBRARYPREP',
#   'LIBRARYTYPE',
#   'METADATATYPE',
#   'MODELSYSTEMTYPE',
#   'NAME',
#   'PLATFORM',
#   'PROJECT',
#   'RESOURCETYPE',
#   'SPECIES',
#   'STUDY',
#   'TABLE',
#   'TYPE'},
#  'SAGE.PORTAL_RAW.GENIE': {'BENEFACTORID',
#   'CONSORTIUM',
#   'CREATEDBY',
#   'CREATEDON',
#   'CURRENTVERSION',
#   'DATAFILEHANDLEID',
#   'DATAFILEMD5HEX',
#   'DATAFILESIZEBYTES',
#   'DATATYPE',
#   'ETAG',
#   'FILEFORMAT',
#   'ID',
#   'MODIFIEDBY',
#   'MODIFIEDON',
#   'NAME',
#   'PARENTID',
#   'PROJECTID',
#   'SPECIES',
#   'TABLE',
#   'TYPE',
#   'VERSION'},
#  'SAGE.PORTAL_RAW.HTAN': {'COMPONENT', 'ENTITYID', 'TABLE'},
#  'SAGE.PORTAL_RAW.NF': {'ACCESSTEAM',
#   'ACCESSTYPE',
#   'AGE',
#   'ASSAY',
#   'BENEFACTORID',
#   'CELLTYPE',
#   'COMPOUNDNAME',
#   'CONSORTIUM',
#   'CONTENTTYPE',
#   'CREATEDBY',
#   'CREATEDON',
#   'DATAFILESIZEBYTES',
#   'DATASUBTYPE',
#   'DATATYPE',
#   'DIAGNOSIS',
#   'ETAG',
#   'EXPERIMENTALCONDITION',
#   'FILEFORMAT',
#   'FUNDINGAGENCY',
#   'GENEPERTURBATIONMETHOD',
#   'GENEPERTURBATIONTYPE',
#   'GENEPERTURBED',
#   'ID',
#   'INDIVIDUALID',
#   'INITIATIVE',
#   'ISCELLLINE',
#   'ISMULTIINDIVIDUAL',
#   'ISMULTISPECIMEN',
#   'ISPAIREDEND',
#   'ISSTRANDED',
#   'ISXENOGRAFT',
#   'LIBRARYPREP',
#   'LIBRARYPREPARATIONMETHOD',
#   'MODELOF',
#   'MODELSYSTEMNAME',
#   'MODIFIEDBY',
#   'MODIFIEDON',
#   'NAME',
#   'NF1GENOTYPE',
#   'NF2GENOTYPE',
#   'PARENTID',
#   'PLATFORM',
#   'PROGRESSREPORTNUMBER',
#   'PROJECTID',
#   'READPAIR',
#   'RESOURCETYPE',
#   'RESOURCE_ID',
#   'SEX',
#   'SPECIES',
#   'SPECIMENID',
#   'STUDYID',
#   'STUDYNAME',
#   'TABLE',
#   'TISSUE',
#   'TRANSPLANTATIONTYPE',
#   'TUMORTYPE',
#   'TYPE'},
#  'SAGE.PORTAL_RAW.PSYCHENCODE': {'ALIGNMENTMETHOD',
#   'ASSAY',
#   'ASSAYTARGET',
#   'BENEFACTORID',
#   'BRODMANNAREA',
#   'CELLTYPE',
#   'CONTRIBUTOR',
#   'CREATEDBY',
#   'CREATEDON',
#   'CURRENTVERSION',
#   'DATAFILEHANDLEID',
#   'DATAFILESIZEBYTES',
#   'DATASUBTYPE',
#   'DATATYPE',
#   'DIAGNOSIS',
#   'ETAG',
#   'FAILEDQC',
#   'FILEFORMAT',
#   'GRANTS',
#   'ID',
#   'INDIVIDUALID',
#   'INDIVIDUALIDSOURCE',
#   'ISMULTIINDIVIDUAL',
#   'ISMULTISPECIMEN',
#   'ISSTRANDED',
#   'LIBRARYBATCH',
#   'LIBRARYPREP',
#   'LIBRARYPREPARATIONMETHOD',
#   'MEANCOVERAGE',
#   'MEANGCCONTENT',
#   'METADATATYPE',
#   'MODIFIEDBY',
#   'MODIFIEDON',
#   'NAME',
#   'NUCLEICACIDSOURCE',
#   'ORGAN',
#   'PARENTID',
#   'PASSAGE',
#   'PH',
#   'PI',
#   'PLATFORM',
#   'PMI',
#   'PROCESSING',
#   'READEND',
#   'READLENGTH',
#   'READSTRANDORIGIN',
#   'REFERENCESET',
#   'REPROGRAMMEDCELLTYPE',
#   'RESOURCETYPE',
#   'RIN',
#   'RNABATCH',
#   'RUNTYPE',
#   'SEQUENCINGBATCH',
#   'SPECIES',
#   'SPECIMENID',
#   'SPECIMENIDSOURCE',
#   'STUDY',
#   'TABLE',
#   'TERMINALDIFFERENTIATIONPOINT',
#   'TISSUE',
#   'TRANSPOSASEBATCH'}}

# %%
# Out:
# {'TABLE'}
